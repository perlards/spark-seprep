# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement ucimlerepo (from versions: none)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.6/libexec/bin/python -m pip install --upgrade pip
# ERROR: No matching distribution found for ucimlerepo
# Note: you may need to restart the kernel to use updated packages.
